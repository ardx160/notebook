# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
import tensorflow_hub as hub
import time
import pandas as pd


from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
data_dir = 'C:\\Users\\ardo\\Documents\\semai\\dataset\\ripeness\\ripeness_v7.2'
print(data_dir)
# Out:
# C:\Users\ardo\Documents\semai\dataset\ripeness\ripeness_v7.2

# %%
batch_size = 32
img_height = 224
img_width = 224

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 593 files belonging to 4 classes.
# Using 475 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 593 files belonging to 4 classes.
# Using 118 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['belum matang', 'jankos', 'lewat matang', 'matang']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
num_classes = 4

model = Sequential([
  data_augmentation,
  normalization_layer,
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 224, 224, 3)       0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 28, 28, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 50176)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               6422656
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 6,446,756
# Trainable params: 6,446,756
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

epochs = 6
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/6
#  2/15 [===>..........................] - ETA: 1s - loss: 1.6924 - accuracy: 0.2344WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0619s vs `on_train_batch_end` time: 0.2095s). Check your callbacks.
# 15/15 [==============================] - 6s 417ms/step - loss: 1.4859 - accuracy: 0.4926 - val_loss: 0.7811 - val_accuracy: 0.6864
# Epoch 2/6
# 15/15 [==============================] - 4s 250ms/step - loss: 0.8351 - accuracy: 0.6800 - val_loss: 0.6992 - val_accuracy: 0.7373
# Epoch 3/6
# 15/15 [==============================] - 4s 269ms/step - loss: 0.6785 - accuracy: 0.7158 - val_loss: 0.6384 - val_accuracy: 0.7203
# Epoch 4/6
# 15/15 [==============================] - 4s 267ms/step - loss: 0.6380 - accuracy: 0.7305 - val_loss: 0.5881 - val_accuracy: 0.7458
# Epoch 5/6
# 15/15 [==============================] - 4s 259ms/step - loss: 0.6046 - accuracy: 0.7579 - val_loss: 0.5600 - val_accuracy: 0.7542
# Epoch 6/6
# 15/15 [==============================] - 4s 271ms/step - loss: 0.5430 - accuracy: 0.7663 - val_loss: 0.6737 - val_accuracy: 0.7542

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
tandan_url = "https://akacn.ac.id/wp-content/uploads/2020/11/tandon-kosong-1.png"
tandan_loc = "C:\\Users\\ardo\\Documents\\personal\\dev\\notebook\\test_ripe_0604\\tandan_kos.jpg"
tandan_path = tf.keras.utils.get_file(tandan_loc, origin=tandan_url)

img = keras.preprocessing.image.load_img(
    tandan_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(predictions)
print(class_names)
print(np.round(score, 3))

print(
    "This image most likely belongs to {} with a {:.1f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)

plt.imshow(img)
# Out:
# [[-1.2254468 -1.1372617  2.7533436  3.7989175]]
# ['belum matang', 'jankos', 'lewat matang', 'matang']
# [0.005 0.005 0.257 0.732]
# This image most likely belongs to matang with a 73.2 percent confidence.

# %%
mobilenet_url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
feature_extractor = hub.KerasLayer(mobilenet_url,
                                   input_shape=(img_height, img_width, 3))

feature_extractor.trainable = False

# %%
num_classes = 4

model = Sequential([
  data_augmentation,
  normalization_layer,
  feature_extractor,
  layers.Dense(256, activation='relu'),
  layers.Dropout(0.5),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 224, 224, 3)       0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 224, 224, 3)       0
# _________________________________________________________________
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               327936
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_10 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 2,619,332
# Trainable params: 361,348
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
early_stop_cuy = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=30, verbose=0,
    mode='auto', baseline=None, restore_best_weights=True
)

model.compile(
  optimizer='adam',
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

epochs = 100
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[early_stop_cuy]
)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 2s 117ms/step - loss: 0.9924 - accuracy: 0.6126 - val_loss: 0.4929 - val_accuracy: 0.7881
# Epoch 2/100
# 15/15 [==============================] - 1s 90ms/step - loss: 0.5240 - accuracy: 0.8189 - val_loss: 0.3461 - val_accuracy: 0.8559
# Epoch 3/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.4098 - accuracy: 0.8442 - val_loss: 0.2422 - val_accuracy: 0.9237
# Epoch 4/100
# 15/15 [==============================] - 1s 91ms/step - loss: 0.2681 - accuracy: 0.9032 - val_loss: 0.1931 - val_accuracy: 0.9153
# Epoch 5/100
# 15/15 [==============================] - 1s 91ms/step - loss: 0.2141 - accuracy: 0.9137 - val_loss: 0.2188 - val_accuracy: 0.9068
# Epoch 6/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.2235 - accuracy: 0.9053 - val_loss: 0.2381 - val_accuracy: 0.9068
# Epoch 7/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.2154 - accuracy: 0.9326 - val_loss: 0.2184 - val_accuracy: 0.9068
# Epoch 8/100
# 15/15 [==============================] - 1s 90ms/step - loss: 0.1871 - accuracy: 0.9284 - val_loss: 0.1660 - val_accuracy: 0.9322
# Epoch 9/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.1827 - accuracy: 0.9305 - val_loss: 0.1764 - val_accuracy: 0.9407
# Epoch 10/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.1695 - accuracy: 0.9368 - val_loss: 0.2203 - val_accuracy: 0.9068
# Epoch 11/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.1975 - accuracy: 0.9347 - val_loss: 0.1674 - val_accuracy: 0.9322
# Epoch 12/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.1725 - accuracy: 0.9326 - val_loss: 0.1824 - val_accuracy: 0.9237
# Epoch 13/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.1469 - accuracy: 0.9495 - val_loss: 0.1980 - val_accuracy: 0.9322
# Epoch 14/100
# 15/15 [==============================] - 1s 91ms/step - loss: 0.1375 - accuracy: 0.9305 - val_loss: 0.1472 - val_accuracy: 0.9492
# Epoch 15/100
# 15/15 [==============================] - 1s 90ms/step - loss: 0.1105 - accuracy: 0.9474 - val_loss: 0.1280 - val_accuracy: 0.9407
# Epoch 16/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.1071 - accuracy: 0.9642 - val_loss: 0.1388 - val_accuracy: 0.9492
# Epoch 17/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0910 - accuracy: 0.9726 - val_loss: 0.1429 - val_accuracy: 0.9576
# Epoch 18/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.1308 - accuracy: 0.9558 - val_loss: 0.1530 - val_accuracy: 0.9322
# Epoch 19/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0839 - accuracy: 0.9600 - val_loss: 0.1326 - val_accuracy: 0.9237
# Epoch 20/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0957 - accuracy: 0.9642 - val_loss: 0.1400 - val_accuracy: 0.9407
# Epoch 21/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.1089 - accuracy: 0.9558 - val_loss: 0.1350 - val_accuracy: 0.9322
# Epoch 22/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.1047 - accuracy: 0.9663 - val_loss: 0.1715 - val_accuracy: 0.9407
# Epoch 23/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.1153 - accuracy: 0.9558 - val_loss: 0.1927 - val_accuracy: 0.9407
# Epoch 24/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0994 - accuracy: 0.9600 - val_loss: 0.1284 - val_accuracy: 0.9322
# Epoch 25/100
# 15/15 [==============================] - 1s 90ms/step - loss: 0.0676 - accuracy: 0.9747 - val_loss: 0.1004 - val_accuracy: 0.9576
# Epoch 26/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0693 - accuracy: 0.9747 - val_loss: 0.1075 - val_accuracy: 0.9492
# Epoch 27/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0482 - accuracy: 0.9768 - val_loss: 0.1305 - val_accuracy: 0.9492
# Epoch 28/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0656 - accuracy: 0.9768 - val_loss: 0.1474 - val_accuracy: 0.9576
# Epoch 29/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0393 - accuracy: 0.9874 - val_loss: 0.1986 - val_accuracy: 0.9322
# Epoch 30/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0658 - accuracy: 0.9747 - val_loss: 0.1810 - val_accuracy: 0.9322
# Epoch 31/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0587 - accuracy: 0.9747 - val_loss: 0.1152 - val_accuracy: 0.9492
# Epoch 32/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0640 - accuracy: 0.9789 - val_loss: 0.1323 - val_accuracy: 0.9492
# Epoch 33/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0779 - accuracy: 0.9811 - val_loss: 0.1980 - val_accuracy: 0.9153
# Epoch 34/100
# 15/15 [==============================] - 1s 93ms/step - loss: 0.0908 - accuracy: 0.9642 - val_loss: 0.0815 - val_accuracy: 0.9746
# Epoch 35/100
# 15/15 [==============================] - 1s 90ms/step - loss: 0.0607 - accuracy: 0.9747 - val_loss: 0.0798 - val_accuracy: 0.9746
# Epoch 36/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0599 - accuracy: 0.9705 - val_loss: 0.1943 - val_accuracy: 0.9407
# Epoch 37/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0803 - accuracy: 0.9705 - val_loss: 0.1146 - val_accuracy: 0.9492
# Epoch 38/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0852 - accuracy: 0.9642 - val_loss: 0.0957 - val_accuracy: 0.9576
# Epoch 39/100
# 15/15 [==============================] - 1s 91ms/step - loss: 0.0473 - accuracy: 0.9853 - val_loss: 0.1488 - val_accuracy: 0.9492
# Epoch 40/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0529 - accuracy: 0.9811 - val_loss: 0.2267 - val_accuracy: 0.9153
# Epoch 41/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0962 - accuracy: 0.9684 - val_loss: 0.1852 - val_accuracy: 0.9153
# Epoch 42/100
# 15/15 [==============================] - 1s 91ms/step - loss: 0.0731 - accuracy: 0.9684 - val_loss: 0.1168 - val_accuracy: 0.9407
# Epoch 43/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0658 - accuracy: 0.9789 - val_loss: 0.1193 - val_accuracy: 0.9576
# Epoch 44/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0550 - accuracy: 0.9747 - val_loss: 0.1024 - val_accuracy: 0.9492
# Epoch 45/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0635 - accuracy: 0.9726 - val_loss: 0.1258 - val_accuracy: 0.9407
# Epoch 46/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0283 - accuracy: 0.9853 - val_loss: 0.1743 - val_accuracy: 0.9576
# Epoch 47/100
# 15/15 [==============================] - 1s 91ms/step - loss: 0.0481 - accuracy: 0.9811 - val_loss: 0.1940 - val_accuracy: 0.9576
# Epoch 48/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0752 - accuracy: 0.9705 - val_loss: 0.1334 - val_accuracy: 0.9576
# Epoch 49/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0437 - accuracy: 0.9853 - val_loss: 0.1448 - val_accuracy: 0.9322
# Epoch 50/100
# 15/15 [==============================] - 1s 90ms/step - loss: 0.0431 - accuracy: 0.9853 - val_loss: 0.1641 - val_accuracy: 0.9492
# Epoch 51/100
# 15/15 [==============================] - 1s 94ms/step - loss: 0.0580 - accuracy: 0.9832 - val_loss: 0.1414 - val_accuracy: 0.9492
# Epoch 52/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0475 - accuracy: 0.9811 - val_loss: 0.1344 - val_accuracy: 0.9576
# Epoch 53/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0623 - accuracy: 0.9747 - val_loss: 0.1171 - val_accuracy: 0.9661
# Epoch 54/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.1073 - accuracy: 0.9621 - val_loss: 0.1721 - val_accuracy: 0.9492
# Epoch 55/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.1208 - accuracy: 0.9537 - val_loss: 0.1600 - val_accuracy: 0.9407
# Epoch 56/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0441 - accuracy: 0.9853 - val_loss: 0.1127 - val_accuracy: 0.9576
# Epoch 57/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0498 - accuracy: 0.9811 - val_loss: 0.2904 - val_accuracy: 0.9068
# Epoch 58/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0969 - accuracy: 0.9621 - val_loss: 0.2368 - val_accuracy: 0.9407
# Epoch 59/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0649 - accuracy: 0.9768 - val_loss: 0.2118 - val_accuracy: 0.9407
# Epoch 60/100
# 15/15 [==============================] - 1s 92ms/step - loss: 0.0926 - accuracy: 0.9726 - val_loss: 0.2465 - val_accuracy: 0.9407
# Epoch 61/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0635 - accuracy: 0.9853 - val_loss: 0.1709 - val_accuracy: 0.9576
# Epoch 62/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0341 - accuracy: 0.9895 - val_loss: 0.1517 - val_accuracy: 0.9492
# Epoch 63/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0584 - accuracy: 0.9768 - val_loss: 0.2089 - val_accuracy: 0.9153
# Epoch 64/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0679 - accuracy: 0.9853 - val_loss: 0.1428 - val_accuracy: 0.9407
# Epoch 65/100
# 15/15 [==============================] - 1s 90ms/step - loss: 0.0278 - accuracy: 0.9874 - val_loss: 0.2367 - val_accuracy: 0.9322

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(65)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
tandan_url = "https://docplayer.info/docs-images/70/62137124/images/31-0.jpg"
tandan_loc = "C:\\Users\\ardo\\Documents\\personal\\dev\\notebook\\test_ripe_0604\\tandan_lewat.jpg"
tandan_path = tf.keras.utils.get_file(tandan_loc, origin=tandan_url)

test_img = "C:\\Users\\ardo\\Documents\\semai\\dataset\\ripeness\\ripeness_v7.1\\belum matang\\4_jpg.rf.6da018ee5194f730fa76294e2ea00131.jpg"

img = keras.preprocessing.image.load_img(
    tandan_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(predictions)
print(class_names)
print(np.round(score, 3))

print(
    "This image most likely belongs to {} with a {:.1f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)

plt.imshow(img)
# Out:
# [[-5.506543   1.4191632  9.626596  -1.0912715]]
# ['belum matang', 'jankos', 'lewat matang', 'matang']
# [0. 0. 1. 0.]
# This image most likely belongs to lewat matang with a 100.0 percent confidence.

# %%
timename = time.strftime("%Y%m%d%H%M%S")
saved_model_path = "ripeness-" + timename + ".h5" # or you can simply use 'my_model.h5'
model.save(saved_model_path) #save your model

# %%
# to reload your model if no snippet keras layer e.g MobileNetV2
#model = keras.models.load_model(saved_model_path)

model = keras.models.load_model(saved_model_path, custom_objects={'KerasLayer':hub.KerasLayer})
#model = keras.models.load_model('ripeness-20210406165324.h5', custom_objects={'KerasLayer':hub.KerasLayer})
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 224, 224, 3)       0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 224, 224, 3)       0
# _________________________________________________________________
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               327936
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_10 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 2,619,332
# Trainable params: 361,348
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
# Get images and labels batch from validation dataset generator
val_image_batch, val_label_batch = next(iter(val_ds))
true_label_ids = np.argmax(val_label_batch, axis=-1)
print("Validation batch shape:", val_image_batch.shape)

# Get predictions for images batch
tf_model_predictions = model.predict(val_image_batch)
score = tf.nn.softmax(tf_model_predictions)
print("Prediction results shape:", score.shape)
score = np.round(score, 4)
# >> Prediction results shape: (32, 5)

# Convert prediction results to Pandas dataframe, for better visualization
tf_pred_dataframe = pd.DataFrame(score)
tf_pred_dataframe.columns = class_names

tf_pred_dataframe.head()
# Out:
# Validation batch shape: (32, 224, 224, 3)
# Prediction results shape: (32, 4)
#    belum matang  jankos  lewat matang  matang
# 0        0.0000     0.0           0.0  1.0000
# 1        1.0000     0.0           0.0  0.0000
# 2        0.0000     0.0           0.0  1.0000
# 3        0.0035     0.0           0.0  0.9964
# 4        1.0000     0.0           0.0  0.0000

# %%
image_batch = val_image_batch.numpy()
label_batch = val_label_batch.numpy()

predicted_batch = model.predict(image_batch)
predicted_batch = tf.squeeze(predicted_batch).numpy()

predicted_ids = np.argmax(predicted_batch, axis=-1)

predicted_class_names = np.array(class_names)[predicted_ids]

print(predicted_class_names)
print("Labels:           ", label_batch)
print("Predicted labels: ", predicted_ids)

plt.figure(figsize=(10,9))
for n in range(30):
  plt.subplot(6,5,n+1)
  plt.subplots_adjust(hspace = 0.3)
  plt.imshow(image_batch[n].astype('uint8'))
  color = "blue" if predicted_ids[n] == label_batch[n] else "red"
  plt.title(predicted_class_names[n].title(), color=color)
  plt.axis('off')
_ = plt.suptitle("Model predictions (blue: correct, red: incorrect)")
# Out:
# ['matang' 'belum matang' 'matang' 'matang' 'belum matang' 'lewat matang'
#  'belum matang' 'lewat matang' 'belum matang' 'matang' 'matang'
#  'belum matang' 'belum matang' 'matang' 'matang' 'matang' 'matang'
#  'lewat matang' 'lewat matang' 'matang' 'belum matang' 'belum matang'
#  'jankos' 'lewat matang' 'matang' 'belum matang' 'lewat matang' 'matang'
#  'jankos' 'belum matang' 'lewat matang' 'matang']
# Labels:            [3 0 3 3 0 2 0 2 0 3 3 0 0 3 3 3 3 2 2 3 0 0 2 2 3 0 2 3 1 0 3 3]
# Predicted labels:  [3 0 3 3 0 2 0 2 0 3 3 0 0 3 3 3 3 2 2 3 0 0 1 2 3 0 2 3 1 0 2 3]

# %%
timename = time.strftime("%Y%m%d%H%M%S")
tflite_path = "ripeness-" + timename + ".tflite"
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open(tflite_path, 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:tensorflow:From C:\Users\ardo\Documents\personal\app\anaconda3\envs\tf-gpu-tflite\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\ardo\Documents\personal\app\anaconda3\envs\tf-gpu-tflite\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\ardo\Documents\personal\app\anaconda3\envs\tf-gpu-tflite\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\ardo\Documents\personal\app\anaconda3\envs\tf-gpu-tflite\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: C:\Users\ardo\AppData\Local\Temp\tmpd7qvfl3v\assets
# INFO:tensorflow:Assets written to: C:\Users\ardo\AppData\Local\Temp\tmpd7qvfl3v\assets

# %%
timename = time.strftime("%Y%m%d%H%M%S")
tflite_q_path = "ripeness-q-" + timename + ".tflite"
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_q_model = converter.convert()
with open(tflite_q_path, 'wb') as f:
  f.write(tflite_q_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\ardo\AppData\Local\Temp\tmpr7lj_zze\assets
# INFO:tensorflow:Assets written to: C:\Users\ardo\AppData\Local\Temp\tmpr7lj_zze\assets

# %%
tflite_interpreter = tf.lite.Interpreter(model_path=tflite_path)
#tflite_interpreter = tf.lite.Interpreter(model_path='ripeness-20210406165419.tflite')

input_details = tflite_interpreter.get_input_details()
output_details = tflite_interpreter.get_output_details()

print("== Input details ==")
print("shape:", input_details[0]['shape'])
print("type:", input_details[0]['dtype'])
print("\n== Output details ==")
print("shape:", output_details[0]['shape'])
print("type:", output_details[0]['dtype'])

print("\n\nAfter Conversion:\n\n")

tflite_interpreter.resize_tensor_input(input_details[0]['index'], (32, 224, 224, 3))
tflite_interpreter.resize_tensor_input(output_details[0]['index'], (32, 5))
tflite_interpreter.allocate_tensors()

input_details = tflite_interpreter.get_input_details()
output_details = tflite_interpreter.get_output_details()

print("== Input details ==")
print("shape:", input_details[0]['shape'])
print("\n== Output details ==")
print("shape:", output_details[0]['shape'])
# Out:
# == Input details ==
# shape: [  1 224 224   3]
# type: <class 'numpy.float32'>
#
# == Output details ==
# shape: [1 4]
# type: <class 'numpy.float32'>
#
#
# After Conversion:
#
#
# == Input details ==
# shape: [ 32 224 224   3]
#
# == Output details ==
# shape: [32  4]

# %%
# Set batch of images into input tensor
tflite_interpreter.set_tensor(input_details[0]['index'], val_image_batch)
# Run inference
tflite_interpreter.invoke()
# Get prediction results
tflite_model_predictions = tflite_interpreter.get_tensor(output_details[0]['index'])

score_tflite = tf.nn.softmax(tflite_model_predictions)
print("Prediction results shape:", score_tflite.shape)
score_tflite = np.round(score_tflite, 4)

# Convert prediction results to Pandas dataframe, for better visualization
tflite_pred_dataframe = pd.DataFrame(score_tflite)
tflite_pred_dataframe.columns = class_names

tflite_pred_dataframe.head()
# Out:
# Prediction results shape: (32, 4)
#    belum matang  jankos  lewat matang  matang
# 0        0.0000     0.0           0.0  1.0000
# 1        1.0000     0.0           0.0  0.0000
# 2        0.0000     0.0           0.0  1.0000
# 3        0.0035     0.0           0.0  0.9964
# 4        1.0000     0.0           0.0  0.0000

# %%
tflite_q_interpreter = tf.lite.Interpreter(model_path=tflite_q_path)
#tflite_q_interpreter = tf.lite.Interpreter(model_path='ripeness-q-20210406165441.tflite')

input_q_details = tflite_q_interpreter.get_input_details()
output_q_details = tflite_q_interpreter.get_output_details()

print("== Input details ==")
print("shape:", input_q_details[0]['shape'])
print("type:", input_q_details[0]['dtype'])
print("\n== Output details ==")
print("shape:", output_q_details[0]['shape'])
print("type:", output_q_details[0]['dtype'])

print("\n\nAfter Conversion:\n\n")

tflite_q_interpreter.resize_tensor_input(input_q_details[0]['index'], (32, 224, 224, 3))
tflite_q_interpreter.resize_tensor_input(output_q_details[0]['index'], (32, 5))
tflite_q_interpreter.allocate_tensors()

input_q_details = tflite_q_interpreter.get_input_details()
output_q_details = tflite_q_interpreter.get_output_details()

print("== Input details ==")
print("shape:", input_q_details[0]['shape'])
print("\n== Output details ==")
print("shape:", output_q_details[0]['shape'])
# Out:
# == Input details ==
# shape: [  1 224 224   3]
# type: <class 'numpy.float32'>
#
# == Output details ==
# shape: [1 4]
# type: <class 'numpy.float32'>
#
#
# After Conversion:
#
#
# == Input details ==
# shape: [ 32 224 224   3]
#
# == Output details ==
# shape: [32  4]

# %%
# Set batch of images into input tensor
tflite_q_interpreter.set_tensor(input_q_details[0]['index'], val_image_batch)
# Run inference
tflite_q_interpreter.invoke()
# Get prediction results
tflite_q_model_predictions = tflite_q_interpreter.get_tensor(output_q_details[0]['index'])
score_tflite_q = tf.nn.softmax(tflite_q_model_predictions)
print("Prediction results shape:", score_tflite_q.shape)
score_tflite_q = np.round(score_tflite_q, 4)


# Convert prediction results to Pandas dataframe, for better visualization
tflite_q_pred_dataframe = pd.DataFrame(score_tflite_q)
tflite_q_pred_dataframe.columns = class_names

tflite_q_pred_dataframe.head()
# Out:
# Prediction results shape: (32, 4)
#    belum matang  jankos  lewat matang  matang
# 0        0.0000  0.0000         0.003  0.9969
# 1        1.0000  0.0000         0.000  0.0000
# 2        0.0000  0.0000         0.000  1.0000
# 3        0.0001  0.0000         0.001  0.9989
# 4        0.9999  0.0001         0.000  0.0000

# %%
tflite_pred_dataframe.head()
# Out:
#    belum matang  jankos  lewat matang  matang
# 0        0.0000     0.0           0.0  1.0000
# 1        1.0000     0.0           0.0  0.0000
# 2        0.0000     0.0           0.0  1.0000
# 3        0.0035     0.0           0.0  0.9964
# 4        1.0000     0.0           0.0  0.0000

# %%
tf_pred_dataframe.head()
# Out:
#    belum matang  jankos  lewat matang  matang
# 0        0.0000     0.0           0.0  1.0000
# 1        1.0000     0.0           0.0  0.0000
# 2        0.0000     0.0           0.0  1.0000
# 3        0.0035     0.0           0.0  0.9964
# 4        1.0000     0.0           0.0  0.0000

# %%
def converttostr(input_seq, seperator):
   # Join all the strings in list
   final_str = seperator.join(input_seq)
   return final_str

labels = converttostr(class_names, '\n')
with open('labels.txt', 'w') as f:
    f.write(labels)
