# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
import tensorflow_hub as hub
import time
import pandas as pd


from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
data_dir = 'C:\\Users\\ardo\\Documents\\semai\\dataset\\ripeness\\ripeness_v7.2'
print(data_dir)
# Out:
# C:\Users\ardo\Documents\semai\dataset\ripeness\ripeness_v7.2

# %%
batch_size = 32
img_height = 224
img_width = 224

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 593 files belonging to 4 classes.
# Using 475 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 593 files belonging to 4 classes.
# Using 118 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['belum matang', 'jankos', 'lewat matang', 'matang']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
num_classes = 4

model = Sequential([
  data_augmentation,
  normalization_layer,
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 224, 224, 3)       0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 28, 28, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 50176)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               6422656
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 6,446,756
# Trainable params: 6,446,756
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

epochs = 6
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/6
# 15/15 [==============================] - 2s 104ms/step - loss: 2.0767 - accuracy: 0.4147 - val_loss: 1.2128 - val_accuracy: 0.4831
# Epoch 2/6
# 15/15 [==============================] - 1s 67ms/step - loss: 1.0370 - accuracy: 0.5937 - val_loss: 0.7385 - val_accuracy: 0.7034
# Epoch 3/6
# 15/15 [==============================] - 1s 68ms/step - loss: 0.7642 - accuracy: 0.7137 - val_loss: 0.6083 - val_accuracy: 0.7373
# Epoch 4/6
# 15/15 [==============================] - 1s 67ms/step - loss: 0.6501 - accuracy: 0.7242 - val_loss: 0.5631 - val_accuracy: 0.7458
# Epoch 5/6
# 15/15 [==============================] - 1s 67ms/step - loss: 0.5893 - accuracy: 0.7537 - val_loss: 0.5488 - val_accuracy: 0.7542
# Epoch 6/6
# 15/15 [==============================] - 1s 66ms/step - loss: 0.5672 - accuracy: 0.7663 - val_loss: 0.5326 - val_accuracy: 0.7627

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
tandan_url = "https://akacn.ac.id/wp-content/uploads/2020/11/tandon-kosong-1.png"
tandan_loc = "C:\\Users\\ardo\\Documents\\personal\\dev\\notebook\\test_ripe_0604\\tandan_kos.jpg"
tandan_path = tf.keras.utils.get_file(tandan_loc, origin=tandan_url)

img = keras.preprocessing.image.load_img(
    tandan_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(predictions)
print(class_names)
print(np.round(score, 3))

print(
    "This image most likely belongs to {} with a {:.1f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)

plt.imshow(img)
# Out:
# [[-1.3552294 -2.570195   3.165552   2.4428594]]
# ['belum matang', 'jankos', 'lewat matang', 'matang']
# [0.007 0.002 0.667 0.324]
# This image most likely belongs to lewat matang with a 66.7 percent confidence.

# %%
mobilenet_url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
feature_extractor = hub.KerasLayer(mobilenet_url,
                                   input_shape=(img_height, img_width, 3))

feature_extractor.trainable = False

# %%
num_classes = 4

model = Sequential([
  data_augmentation,
  normalization_layer,
  feature_extractor,
  layers.Dense(256, activation='relu'),
  layers.Dropout(0.5),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 224, 224, 3)       0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 224, 224, 3)       0
# _________________________________________________________________
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dense_29 (Dense)             (None, 256)               327936
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_31 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 2,619,332
# Trainable params: 361,348
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
early_stop_cuy = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=30, verbose=0,
    mode='auto', baseline=None, restore_best_weights=True
)

model.compile(
  optimizer='adam',
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

epochs = 100
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[early_stop_cuy]
)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 2s 114ms/step - loss: 0.9630 - accuracy: 0.6421 - val_loss: 0.4604 - val_accuracy: 0.8390
# Epoch 2/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.5806 - accuracy: 0.7979 - val_loss: 0.3095 - val_accuracy: 0.9237
# Epoch 3/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.3801 - accuracy: 0.8484 - val_loss: 0.2906 - val_accuracy: 0.8983
# Epoch 4/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.3224 - accuracy: 0.8947 - val_loss: 0.2515 - val_accuracy: 0.8898
# Epoch 5/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.3064 - accuracy: 0.8716 - val_loss: 0.2444 - val_accuracy: 0.9068
# Epoch 6/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.2625 - accuracy: 0.9158 - val_loss: 0.2519 - val_accuracy: 0.9068
# Epoch 7/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.2161 - accuracy: 0.9200 - val_loss: 0.2765 - val_accuracy: 0.8814
# Epoch 8/100
# 15/15 [==============================] - 1s 91ms/step - loss: 0.1767 - accuracy: 0.9389 - val_loss: 0.2438 - val_accuracy: 0.8814
# Epoch 9/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.1744 - accuracy: 0.9411 - val_loss: 0.2454 - val_accuracy: 0.8814
# Epoch 10/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.1540 - accuracy: 0.9432 - val_loss: 0.2286 - val_accuracy: 0.9068
# Epoch 11/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.1157 - accuracy: 0.9537 - val_loss: 0.1487 - val_accuracy: 0.9576
# Epoch 12/100
# 15/15 [==============================] - 1s 90ms/step - loss: 0.1261 - accuracy: 0.9516 - val_loss: 0.1314 - val_accuracy: 0.9492
# Epoch 13/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.1345 - accuracy: 0.9347 - val_loss: 0.2012 - val_accuracy: 0.9237
# Epoch 14/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.1059 - accuracy: 0.9495 - val_loss: 0.1773 - val_accuracy: 0.9407
# Epoch 15/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0947 - accuracy: 0.9705 - val_loss: 0.1529 - val_accuracy: 0.9322
# Epoch 16/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0812 - accuracy: 0.9684 - val_loss: 0.1468 - val_accuracy: 0.9237
# Epoch 17/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0723 - accuracy: 0.9705 - val_loss: 0.1956 - val_accuracy: 0.9322
# Epoch 18/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.1135 - accuracy: 0.9663 - val_loss: 0.2105 - val_accuracy: 0.9237
# Epoch 19/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.1270 - accuracy: 0.9537 - val_loss: 0.1557 - val_accuracy: 0.9576
# Epoch 20/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.1017 - accuracy: 0.9600 - val_loss: 0.1789 - val_accuracy: 0.9068
# Epoch 21/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0855 - accuracy: 0.9642 - val_loss: 0.1662 - val_accuracy: 0.9322
# Epoch 22/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.1113 - accuracy: 0.9495 - val_loss: 0.2530 - val_accuracy: 0.9068
# Epoch 23/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.1313 - accuracy: 0.9537 - val_loss: 0.2291 - val_accuracy: 0.9322
# Epoch 24/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0833 - accuracy: 0.9705 - val_loss: 0.1183 - val_accuracy: 0.9576
# Epoch 25/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0710 - accuracy: 0.9684 - val_loss: 0.1364 - val_accuracy: 0.9492
# Epoch 26/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0823 - accuracy: 0.9684 - val_loss: 0.1981 - val_accuracy: 0.9153
# Epoch 27/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0704 - accuracy: 0.9789 - val_loss: 0.2465 - val_accuracy: 0.9068
# Epoch 28/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.1001 - accuracy: 0.9600 - val_loss: 0.1724 - val_accuracy: 0.9322
# Epoch 29/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0762 - accuracy: 0.9747 - val_loss: 0.1925 - val_accuracy: 0.8983
# Epoch 30/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.1032 - accuracy: 0.9621 - val_loss: 0.2209 - val_accuracy: 0.9407
# Epoch 31/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.1086 - accuracy: 0.9579 - val_loss: 0.1479 - val_accuracy: 0.9492
# Epoch 32/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.1054 - accuracy: 0.9642 - val_loss: 0.1154 - val_accuracy: 0.9407
# Epoch 33/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0768 - accuracy: 0.9705 - val_loss: 0.0865 - val_accuracy: 0.9576
# Epoch 34/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0667 - accuracy: 0.9705 - val_loss: 0.1351 - val_accuracy: 0.9407
# Epoch 35/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0481 - accuracy: 0.9832 - val_loss: 0.1391 - val_accuracy: 0.9492
# Epoch 36/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0556 - accuracy: 0.9789 - val_loss: 0.1016 - val_accuracy: 0.9492
# Epoch 37/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0555 - accuracy: 0.9726 - val_loss: 0.1415 - val_accuracy: 0.9492
# Epoch 38/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0617 - accuracy: 0.9789 - val_loss: 0.1994 - val_accuracy: 0.9237
# Epoch 39/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0534 - accuracy: 0.9811 - val_loss: 0.1357 - val_accuracy: 0.9322
# Epoch 40/100
# 15/15 [==============================] - 1s 91ms/step - loss: 0.0577 - accuracy: 0.9789 - val_loss: 0.1856 - val_accuracy: 0.9407
# Epoch 41/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0629 - accuracy: 0.9768 - val_loss: 0.2099 - val_accuracy: 0.9407
# Epoch 42/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0344 - accuracy: 0.9895 - val_loss: 0.1460 - val_accuracy: 0.9492
# Epoch 43/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0713 - accuracy: 0.9811 - val_loss: 0.1357 - val_accuracy: 0.9492
# Epoch 44/100
# 15/15 [==============================] - 1s 84ms/step - loss: 0.0525 - accuracy: 0.9853 - val_loss: 0.1102 - val_accuracy: 0.9492
# Epoch 45/100
# 15/15 [==============================] - 1s 84ms/step - loss: 0.0711 - accuracy: 0.9726 - val_loss: 0.1707 - val_accuracy: 0.9576
# Epoch 46/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0426 - accuracy: 0.9832 - val_loss: 0.1090 - val_accuracy: 0.9492
# Epoch 47/100
# 15/15 [==============================] - 1s 84ms/step - loss: 0.0451 - accuracy: 0.9895 - val_loss: 0.1339 - val_accuracy: 0.9492
# Epoch 48/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0542 - accuracy: 0.9789 - val_loss: 0.1328 - val_accuracy: 0.9407
# Epoch 49/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0794 - accuracy: 0.9663 - val_loss: 0.1733 - val_accuracy: 0.9237
# Epoch 50/100
# 15/15 [==============================] - 1s 84ms/step - loss: 0.0896 - accuracy: 0.9726 - val_loss: 0.1885 - val_accuracy: 0.9237
# Epoch 51/100
# 15/15 [==============================] - 1s 83ms/step - loss: 0.0615 - accuracy: 0.9789 - val_loss: 0.1446 - val_accuracy: 0.9492
# Epoch 52/100
# 15/15 [==============================] - 1s 83ms/step - loss: 0.0485 - accuracy: 0.9768 - val_loss: 0.2700 - val_accuracy: 0.8898
# Epoch 53/100
# 15/15 [==============================] - 1s 84ms/step - loss: 0.0582 - accuracy: 0.9726 - val_loss: 0.1820 - val_accuracy: 0.9492
# Epoch 54/100
# 15/15 [==============================] - 1s 84ms/step - loss: 0.0332 - accuracy: 0.9789 - val_loss: 0.1714 - val_accuracy: 0.9237
# Epoch 55/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0402 - accuracy: 0.9811 - val_loss: 0.1890 - val_accuracy: 0.9407
# Epoch 56/100
# 15/15 [==============================] - 1s 92ms/step - loss: 0.0526 - accuracy: 0.9874 - val_loss: 0.1396 - val_accuracy: 0.9492
# Epoch 57/100
# 15/15 [==============================] - 1s 91ms/step - loss: 0.0473 - accuracy: 0.9811 - val_loss: 0.2377 - val_accuracy: 0.9237
# Epoch 58/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0309 - accuracy: 0.9874 - val_loss: 0.1588 - val_accuracy: 0.9407
# Epoch 59/100
# 15/15 [==============================] - 1s 93ms/step - loss: 0.0241 - accuracy: 0.9916 - val_loss: 0.0792 - val_accuracy: 0.9576
# Epoch 60/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0503 - accuracy: 0.9705 - val_loss: 0.2379 - val_accuracy: 0.9322
# Epoch 61/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0531 - accuracy: 0.9768 - val_loss: 0.1273 - val_accuracy: 0.9492
# Epoch 62/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0358 - accuracy: 0.9874 - val_loss: 0.1298 - val_accuracy: 0.9322
# Epoch 63/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0811 - accuracy: 0.9789 - val_loss: 0.1147 - val_accuracy: 0.9492
# Epoch 64/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0505 - accuracy: 0.9832 - val_loss: 0.1620 - val_accuracy: 0.9492
# Epoch 65/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0930 - accuracy: 0.9705 - val_loss: 0.2237 - val_accuracy: 0.9407
# Epoch 66/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0490 - accuracy: 0.9811 - val_loss: 0.1984 - val_accuracy: 0.9492
# Epoch 67/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0360 - accuracy: 0.9916 - val_loss: 0.2050 - val_accuracy: 0.9407
# Epoch 68/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0344 - accuracy: 0.9832 - val_loss: 0.2396 - val_accuracy: 0.9492
# Epoch 69/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0357 - accuracy: 0.9874 - val_loss: 0.1421 - val_accuracy: 0.9492
# Epoch 70/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0491 - accuracy: 0.9789 - val_loss: 0.0709 - val_accuracy: 0.9661
# Epoch 71/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0359 - accuracy: 0.9874 - val_loss: 0.2100 - val_accuracy: 0.9322
# Epoch 72/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0442 - accuracy: 0.9747 - val_loss: 0.1109 - val_accuracy: 0.9492
# Epoch 73/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0660 - accuracy: 0.9747 - val_loss: 0.1102 - val_accuracy: 0.9661
# Epoch 74/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0277 - accuracy: 0.9916 - val_loss: 0.1095 - val_accuracy: 0.9492
# Epoch 75/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0270 - accuracy: 0.9916 - val_loss: 0.1601 - val_accuracy: 0.9661
# Epoch 76/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0606 - accuracy: 0.9768 - val_loss: 0.1662 - val_accuracy: 0.9492
# Epoch 77/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0517 - accuracy: 0.9853 - val_loss: 0.1664 - val_accuracy: 0.9492
# Epoch 78/100
# 15/15 [==============================] - 1s 90ms/step - loss: 0.0774 - accuracy: 0.9768 - val_loss: 0.1150 - val_accuracy: 0.9576
# Epoch 79/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0529 - accuracy: 0.9832 - val_loss: 0.1212 - val_accuracy: 0.9492
# Epoch 80/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0510 - accuracy: 0.9789 - val_loss: 0.1633 - val_accuracy: 0.9492
# Epoch 81/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 0.1186 - val_accuracy: 0.9492
# Epoch 82/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0370 - accuracy: 0.9853 - val_loss: 0.1782 - val_accuracy: 0.9492
# Epoch 83/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0138 - accuracy: 0.9979 - val_loss: 0.1591 - val_accuracy: 0.9576
# Epoch 84/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0245 - accuracy: 0.9895 - val_loss: 0.0822 - val_accuracy: 0.9576
# Epoch 85/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0570 - accuracy: 0.9832 - val_loss: 0.2256 - val_accuracy: 0.9237
# Epoch 86/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0296 - accuracy: 0.9895 - val_loss: 0.0956 - val_accuracy: 0.9492
# Epoch 87/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0262 - accuracy: 0.9916 - val_loss: 0.1737 - val_accuracy: 0.9576
# Epoch 88/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0235 - accuracy: 0.9895 - val_loss: 0.1903 - val_accuracy: 0.9492
# Epoch 89/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0392 - accuracy: 0.9895 - val_loss: 0.1745 - val_accuracy: 0.9576
# Epoch 90/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0367 - accuracy: 0.9895 - val_loss: 0.2102 - val_accuracy: 0.9407
# Epoch 91/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0324 - accuracy: 0.9853 - val_loss: 0.1033 - val_accuracy: 0.9407
# Epoch 92/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0256 - accuracy: 0.9895 - val_loss: 0.0798 - val_accuracy: 0.9746
# Epoch 93/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0418 - accuracy: 0.9853 - val_loss: 0.1444 - val_accuracy: 0.9661
# Epoch 94/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0325 - accuracy: 0.9874 - val_loss: 0.1623 - val_accuracy: 0.9661
# Epoch 95/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0368 - accuracy: 0.9895 - val_loss: 0.1811 - val_accuracy: 0.9576
# Epoch 96/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0503 - accuracy: 0.9853 - val_loss: 0.1839 - val_accuracy: 0.9576
# Epoch 97/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0683 - accuracy: 0.9811 - val_loss: 0.0956 - val_accuracy: 0.9576
# Epoch 98/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0436 - accuracy: 0.9832 - val_loss: 0.0963 - val_accuracy: 0.9492
# Epoch 99/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0243 - accuracy: 0.9937 - val_loss: 0.1904 - val_accuracy: 0.9407
# Epoch 100/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0240 - accuracy: 0.9916 - val_loss: 0.2907 - val_accuracy: 0.9322

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(100)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
tandan_url = "https://docplayer.info/docs-images/70/62137124/images/31-0.jpg"
tandan_loc = "C:\\Users\\ardo\\Documents\\personal\\dev\\notebook\\test_ripe_0604\\tandan_lewat.jpg"
tandan_path = tf.keras.utils.get_file(tandan_loc, origin=tandan_url)

test_img = "C:\\Users\\ardo\\Documents\\semai\\dataset\\ripeness\\ripeness_v7.1\\belum matang\\4_jpg.rf.6da018ee5194f730fa76294e2ea00131.jpg"

img = keras.preprocessing.image.load_img(
    tandan_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(predictions)
print(class_names)
print(np.round(score, 3))

print(
    "This image most likely belongs to {} with a {:.1f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)

plt.imshow(img)
# Out:
# [[-7.9886246   2.6173222  11.862813    0.53117543]]
# ['belum matang', 'jankos', 'lewat matang', 'matang']
# [0. 0. 1. 0.]
# This image most likely belongs to lewat matang with a 100.0 percent confidence.

# %%
test = [20.0, 40.0, 30.0, 10.0]
hasil = tf.nn.softmax(test)
print(np.round(hasil, 3))
# Out:
# [0. 1. 0. 0.]

# %%
timename = time.strftime("%Y%m%d%H%M%S")
saved_model_path = "ripeness-" + timename + ".h5" # or you can simply use 'my_model.h5'
model.save(saved_model_path) #save your model

# %%
# to reload your model if no snippet keras layer e.g MobileNetV2
#model = keras.models.load_model(saved_model_path)

model = keras.models.load_model(saved_model_path, custom_objects={'KerasLayer':hub.KerasLayer})
#model = keras.models.load_model('ripeness-20210406165324.h5', custom_objects={'KerasLayer':hub.KerasLayer})
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 224, 224, 3)       0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 224, 224, 3)       0
# _________________________________________________________________
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dense_29 (Dense)             (None, 256)               327936
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_31 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 2,619,332
# Trainable params: 361,348
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
# Get images and labels batch from validation dataset generator
val_image_batch, val_label_batch = next(iter(val_ds))
true_label_ids = np.argmax(val_label_batch, axis=-1)
print("Validation batch shape:", val_image_batch.shape)

# Get predictions for images batch
tf_model_predictions = model.predict(val_image_batch)
score = tf.nn.softmax(tf_model_predictions)
print("Prediction results shape:", score.shape)
score = np.round(score, 4)
# >> Prediction results shape: (32, 5)

# Convert prediction results to Pandas dataframe, for better visualization
tf_pred_dataframe = pd.DataFrame(score)
tf_pred_dataframe.columns = class_names

tf_pred_dataframe.head()
# Out:
# Validation batch shape: (32, 224, 224, 3)
# WARNING:tensorflow:5 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019586963430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019586963430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Prediction results shape: (32, 4)
#    belum matang  jankos  lewat matang  matang
# 0        0.0000  0.0000        0.0000  1.0000
# 1        0.0000  0.0000        0.0000  1.0000
# 2        0.0026  0.0000        0.0000  0.9974
# 3        0.0229  0.0019        0.9085  0.0666
# 4        1.0000  0.0000        0.0000  0.0000

# %%
tf_pred_dataframe_ori = pd.DataFrame(tf_model_predictions)
tf_pred_dataframe_ori.columns = class_names

tf_pred_dataframe_ori.head()
# Out:
#    belum matang     jankos  lewat matang     matang
# 0      2.250123 -11.044224      0.369902  15.936939
# 1     -0.351322 -10.678393      1.209300  19.717903
# 2      1.772419  -3.694313     -2.631926   7.735608
# 3      0.112116  -2.357514      3.791956   1.178802
# 4     15.478026  -2.477360     -7.097785  -6.768435

# %%
image_batch = val_image_batch.numpy()
label_batch = val_label_batch.numpy()

predicted_batch = model.predict(image_batch)
predicted_batch = tf.squeeze(predicted_batch).numpy()

predicted_ids = np.argmax(predicted_batch, axis=-1)

predicted_class_names = np.array(class_names)[predicted_ids]

print(predicted_class_names)
print("Labels:           ", label_batch)
print("Predicted labels: ", predicted_ids)

plt.figure(figsize=(10,9))
for n in range(30):
  plt.subplot(6,5,n+1)
  plt.subplots_adjust(hspace = 0.3)
  plt.imshow(image_batch[n].astype('uint8'))
  color = "blue" if predicted_ids[n] == label_batch[n] else "red"
  plt.title(predicted_class_names[n].title(), color=color)
  plt.axis('off')
_ = plt.suptitle("Model predictions (blue: correct, red: incorrect)")
# Out:
# ['matang' 'matang' 'matang' 'lewat matang' 'belum matang' 'belum matang'
#  'matang' 'jankos' 'lewat matang' 'lewat matang' 'lewat matang'
#  'lewat matang' 'belum matang' 'belum matang' 'matang' 'belum matang'
#  'matang' 'belum matang' 'lewat matang' 'matang' 'matang' 'belum matang'
#  'belum matang' 'lewat matang' 'belum matang' 'belum matang' 'matang'
#  'lewat matang' 'matang' 'matang' 'matang' 'lewat matang']
# Labels:            [3 3 3 2 0 0 3 1 2 2 2 2 0 0 3 0 3 0 2 3 3 0 0 2 0 0 3 2 3 3 3 2]
# Predicted labels:  [3 3 3 2 0 0 3 1 2 2 2 2 0 0 3 0 3 0 2 3 3 0 0 2 0 0 3 2 3 3 3 2]

# %%
timename = time.strftime("%Y%m%d%H%M%S")
tflite_path = "ripeness-" + timename + ".tflite"
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open(tflite_path, 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:tensorflow:From C:\Users\ardo\Documents\personal\app\anaconda3\envs\tf-gpu-tflite\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\ardo\Documents\personal\app\anaconda3\envs\tf-gpu-tflite\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\ardo\Documents\personal\app\anaconda3\envs\tf-gpu-tflite\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\ardo\Documents\personal\app\anaconda3\envs\tf-gpu-tflite\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: C:\Users\ardo\AppData\Local\Temp\tmppnyeq3j1\assets
# INFO:tensorflow:Assets written to: C:\Users\ardo\AppData\Local\Temp\tmppnyeq3j1\assets

# %%
timename = time.strftime("%Y%m%d%H%M%S")
tflite_q_path = "ripeness-q-" + timename + ".tflite"
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_q_model = converter.convert()
with open(tflite_q_path, 'wb') as f:
  f.write(tflite_q_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\ardo\AppData\Local\Temp\tmpj07obds6\assets
# INFO:tensorflow:Assets written to: C:\Users\ardo\AppData\Local\Temp\tmpj07obds6\assets

# %%
tflite_interpreter = tf.lite.Interpreter(model_path=tflite_path)
#tflite_interpreter = tf.lite.Interpreter(model_path='ripeness-20210406165419.tflite')

input_details = tflite_interpreter.get_input_details()
output_details = tflite_interpreter.get_output_details()

print("== Input details ==")
print("shape:", input_details[0]['shape'])
print("type:", input_details[0]['dtype'])
print("\n== Output details ==")
print("shape:", output_details[0]['shape'])
print("type:", output_details[0]['dtype'])

print("\n\nAfter Conversion:\n\n")

tflite_interpreter.resize_tensor_input(input_details[0]['index'], (32, 224, 224, 3))
tflite_interpreter.resize_tensor_input(output_details[0]['index'], (32, 5))
tflite_interpreter.allocate_tensors()

input_details = tflite_interpreter.get_input_details()
output_details = tflite_interpreter.get_output_details()

print("== Input details ==")
print("shape:", input_details[0]['shape'])
print("\n== Output details ==")
print("shape:", output_details[0]['shape'])
# Out:
# == Input details ==
# shape: [  1 224 224   3]
# type: <class 'numpy.float32'>
#
# == Output details ==
# shape: [1 4]
# type: <class 'numpy.float32'>
#
#
# After Conversion:
#
#
# == Input details ==
# shape: [ 32 224 224   3]
#
# == Output details ==
# shape: [32  4]

# %%
# Set batch of images into input tensor
tflite_interpreter.set_tensor(input_details[0]['index'], val_image_batch)
# Run inference
tflite_interpreter.invoke()
# Get prediction results
tflite_model_predictions = tflite_interpreter.get_tensor(output_details[0]['index'])

score_tflite = tf.nn.softmax(tflite_model_predictions)
print("Prediction results shape:", score_tflite.shape)
score_tflite = np.round(score_tflite, 4)

# Convert prediction results to Pandas dataframe, for better visualization
tflite_pred_dataframe = pd.DataFrame(score_tflite)
tflite_pred_dataframe.columns = class_names

tflite_pred_dataframe.head()
# Out:
# Prediction results shape: (32, 4)
#    belum matang  jankos  lewat matang  matang
# 0        0.0000  0.0000        0.0000  1.0000
# 1        0.0000  0.0000        0.0000  1.0000
# 2        0.0026  0.0000        0.0000  0.9974
# 3        0.0229  0.0019        0.9085  0.0666
# 4        1.0000  0.0000        0.0000  0.0000

# %%
tflite_pred_dataframe_ori = pd.DataFrame(tflite_model_predictions)
tflite_pred_dataframe_ori.columns = class_names

tflite_pred_dataframe_ori.head()
# Out:
#    belum matang     jankos  lewat matang     matang
# 0      2.250126 -11.044214      0.369900  15.936935
# 1     -0.351331 -10.678396      1.209307  19.717915
# 2      1.772412  -3.694308     -2.631926   7.735605
# 3      0.112119  -2.357504      3.791968   1.178776
# 4     15.478036  -2.477357     -7.097792  -6.768440

# %%
tflite_q_interpreter = tf.lite.Interpreter(model_path=tflite_q_path)
#tflite_q_interpreter = tf.lite.Interpreter(model_path='ripeness-q-20210406165441.tflite')

input_q_details = tflite_q_interpreter.get_input_details()
output_q_details = tflite_q_interpreter.get_output_details()

print("== Input details ==")
print("shape:", input_q_details[0]['shape'])
print("type:", input_q_details[0]['dtype'])
print("\n== Output details ==")
print("shape:", output_q_details[0]['shape'])
print("type:", output_q_details[0]['dtype'])

print("\n\nAfter Conversion:\n\n")

tflite_q_interpreter.resize_tensor_input(input_q_details[0]['index'], (32, 224, 224, 3))
tflite_q_interpreter.resize_tensor_input(output_q_details[0]['index'], (32, 5))
tflite_q_interpreter.allocate_tensors()

input_q_details = tflite_q_interpreter.get_input_details()
output_q_details = tflite_q_interpreter.get_output_details()

print("== Input details ==")
print("shape:", input_q_details[0]['shape'])
print("\n== Output details ==")
print("shape:", output_q_details[0]['shape'])
# Out:
# == Input details ==
# shape: [  1 224 224   3]
# type: <class 'numpy.float32'>
#
# == Output details ==
# shape: [1 4]
# type: <class 'numpy.float32'>
#
#
# After Conversion:
#
#
# == Input details ==
# shape: [ 32 224 224   3]
#
# == Output details ==
# shape: [32  4]

# %%
# Set batch of images into input tensor
tflite_q_interpreter.set_tensor(input_q_details[0]['index'], val_image_batch)
# Run inference
tflite_q_interpreter.invoke()
# Get prediction results
tflite_q_model_predictions = tflite_q_interpreter.get_tensor(output_q_details[0]['index'])
score_tflite_q = tf.nn.softmax(tflite_q_model_predictions)
print("Prediction results shape:", score_tflite_q.shape)
score_tflite_q = np.round(score_tflite_q, 4)


# Convert prediction results to Pandas dataframe, for better visualization
tflite_q_pred_dataframe = pd.DataFrame(score_tflite_q)
tflite_q_pred_dataframe.columns = class_names

tflite_q_pred_dataframe.head()
# Out:
# Prediction results shape: (32, 4)
#    belum matang  jankos  lewat matang  matang
# 0        0.0000  0.0000        0.0000  1.0000
# 1        0.0002  0.0000        0.0001  0.9997
# 2        0.0009  0.0000        0.0000  0.9991
# 3        0.0081  0.0003        0.0401  0.9515
# 4        1.0000  0.0000        0.0000  0.0000

# %%
tflite_q_pred_dataframe_ori = pd.DataFrame(tflite_q_model_predictions)
tflite_q_pred_dataframe_ori.columns = class_names

tflite_q_pred_dataframe_ori.head()
# Out:
#    belum matang    jankos  lewat matang     matang
# 0      3.348222 -9.594945     -1.655771  13.738567
# 1      0.799287 -6.378065      0.145410   9.499137
# 2      2.097670 -5.597918     -2.016993   9.127957
# 3      0.153335 -3.142769      1.751649   4.919019
# 4     12.898849  0.088709     -5.773232  -8.766808

# %%
tflite_pred_dataframe.head()
# Out:
#    belum matang  jankos  lewat matang  matang
# 0        0.0000  0.0000        0.0000  1.0000
# 1        0.0000  0.0000        0.0000  1.0000
# 2        0.0026  0.0000        0.0000  0.9974
# 3        0.0229  0.0019        0.9085  0.0666
# 4        1.0000  0.0000        0.0000  0.0000

# %%
tflite_pred_dataframe_ori.head()
# Out:
#    belum matang     jankos  lewat matang     matang
# 0      2.250126 -11.044214      0.369900  15.936935
# 1     -0.351331 -10.678396      1.209307  19.717915
# 2      1.772412  -3.694308     -2.631926   7.735605
# 3      0.112119  -2.357504      3.791968   1.178776
# 4     15.478036  -2.477357     -7.097792  -6.768440

# %%
tf_pred_dataframe.head()
# Out:
#    belum matang  jankos  lewat matang  matang
# 0        0.0000  0.0000        0.0000  1.0000
# 1        0.0000  0.0000        0.0000  1.0000
# 2        0.0026  0.0000        0.0000  0.9974
# 3        0.0229  0.0019        0.9085  0.0666
# 4        1.0000  0.0000        0.0000  0.0000

# %%
tf_pred_dataframe_ori.head()
# Out:
#    belum matang     jankos  lewat matang     matang
# 0      2.250123 -11.044224      0.369902  15.936939
# 1     -0.351322 -10.678393      1.209300  19.717903
# 2      1.772419  -3.694313     -2.631926   7.735608
# 3      0.112116  -2.357514      3.791956   1.178802
# 4     15.478026  -2.477360     -7.097785  -6.768435

# %%
def converttostr(input_seq, seperator):
   # Join all the strings in list
   final_str = seperator.join(input_seq)
   return final_str

labels = converttostr(class_names, '\n')
with open('labels.txt', 'w') as f:
    f.write(labels)
